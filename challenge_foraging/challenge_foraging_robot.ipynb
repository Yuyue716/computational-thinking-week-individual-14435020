# %% [markdown]
# # Foraging Robot Exercise
# In this individual exercise, you will write heuristics for a foraging robot so that it can efficiently gather fruits and berries in the forest. Your goal is to collect as much as you can!
#
# ## Learning goals
# Refresh your knowledge of semester 2 statistics:
# - Probability
# - Probability distributions
# - Conditional probabilities
#
# ## Overview
# As for all individual exercises, you are expected to complete the bronze level, but silver and gold levels are fully optional.
#
# Bronze Level (~1 hour)
# - Introduction to the scenario
# - Estimate distributions from samples
# - Calculate cumulative distribution functions
#
# Silver Level (~1 hour)
# - Conditional probabilities
#
# Gold Level (~2.5 hours)
# - Making a strategy

# %%
# Imports
from IPython.display import Image
import numpy as np
import seaborn as sns

from tests import tests

# %% [markdown]
# ## Bronze Level: Your foraging robot
#
# Congratulations on acquiring your own ForageBot 3000. This robot can autonomously collect fruits and berries from your local forest.
# Let's import and initialize our robot:

# %%
from scenario.forage_bot import ForageBot, Tree, BerryBush

forageBot = ForageBot()

# %% [markdown]
# In the step above, we import the ForageBot class from a different file (module). We then initialize an instance of this class as *forageBot*.
# You have probably used classes before, such as DataFrames from the pandas module. All the methods (functions) and attributes (variables) of ForageBot() will be explained when we first use them, but if you want to have a look, you can also check out the scenario file to see the class definition.
#
# The most important ability of your ForageBot, of course, is to forage. Every day, you can send out your robot to forage from one location.
# During our initital survey of your local forest, we identified two nearby apple trees. Let's send your new robot to one of these trees to collect apples.

# %%
tree_one = ForageBot.pre_survey['tree_one']

forageBot.forage(tree_one, verbose=True);
# Out:
# The robot collected 2.60kg of apples

# %% [markdown]
# Well done! You've collected your first apples.
# Now, try running the cell above a few more times. You will notice, that the amount of apples you collect changes every time. Even though you are collecting from the same tree, the yield for the day is random.
# Now, try collecting apples from the second tree a few times:

# %%
tree_two = ForageBot.pre_survey['tree_two']
#np.random.seed(42)
forageBot.forage(tree_two, verbose=True);
# Out:
# The robot collected 5.56kg of apples

# %% [markdown]
# Did you notice a difference?
# The second tree seems to usually yield more apples. However, it's sometimes possible to collect more apples from tree one than from tree two.
#
# Later, we will go explore the forest and find new trees. Of course, we would like to find the best trees which yield us the most apples.
# Given that the amount of apples for any day is random, we should try to find the __expected result__ from any given tree.
# The easiest way to do this, would be to estimate the __average__ amount of apples we collect from any tree.
# Try below to calculate the mean amount of apples collected from a tree.
# It's as simple as summing up all the values you collected, and then dividing by the number of samples that you collected.
#
# Complete the function below by filling in the '...'

# %%
def mean_tree_yield(tree, iterations=100) -> float:
    """ Collects from a tree multiple times, and then returns the mean yield.

    Args:
        tree: Reference to the tree which we forage (sample) from.
        iterations: The number of samples to collect.
    """
    # Create an empty list of samples
    samples = []
    # Collect one new sample from the given tree in each iteration using the forage() function of our bot.
    for i in range(iterations):
        samples.append(forageBot.forage(tree))
    average_samples = sum(samples)/len(samples)
    # Calculate and return the mean
    return average_samples

mean_result = mean_tree_yield(tree_two)
print(f'After 100 iterations, the mean yield from this tree was: {mean_result:.02f}kg')

# This function is graded. You can uncomment the line below to test whether your function passes.
tests.Test_MeanTreeYield(mean_tree_yield);
# Out:
# After 100 iterations, the mean yield from this tree was: 5.07kg
# All tests passed

# %% [markdown]
# If you rerun the cell above, you will notice that the mean yield still changes every time, since we are only estimating it from 100 samples. Nevertheless, our estimate is now much more consistent than any single sample was.
#
# While the mean is often a useful metric, we might get an even better idea of what each apple tree yields if we plot the distribution of apples. Complete the code below to do just that.

# %%
def plot_distribution(samples, color='blue') -> None:
    """ Plots the distribution of collected samples.

    Args:
        samples: A list of samples from a distribution.
        color: Name of the color in which to draw the distribution
    """

    # Hint: Use the histplot function of seaborn (imported as sns)
    
    return sns.histplot(samples,color=color)



# Set random seed so output matches the expected output
np.random.seed(42)
# Collect from a tree 500 times
samples = [forageBot.forage(tree_two) for i in range(500)]
plot_distribution(samples)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# You should generate this image:
#
# <img src="resources/plot1.png" alt="Distribution plot for tree_two" width="200"/>
#
# Now let's compare the two trees:

# %%
# Set random seed so output matches the expected output
np.random.seed(42)

# Collect from both trees
samples_one = [forageBot.forage(tree_one) for i in range(500)]
samples_two = [forageBot.forage(tree_two) for i in range(500)]

# Plot distributions
plot_distribution(samples_one, color='blue')
plot_distribution(samples_two, color='red')
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# You should generate this image:
#
# <img src="resources/plot2.png" alt="Distribution plot for tree_two" width="200"/>
#
# You can see that the distributions from both apple trees have a similar shape, but that tree two tends to give more apples than tree one.
#
# Now, let's have a look at two more trees

# %%
tree_three = ForageBot.pre_survey['tree_three']
tree_four = ForageBot.pre_survey['tree_four']

# Set random seed so output matches the expected output
np.random.seed(42)

# Collect from both trees
samples_three = [forageBot.forage(tree_three) for i in range(500)]
samples_four = [forageBot.forage(tree_four) for i in range(500)]

# Plot distributions
plot_distribution(samples_three, color='blue')
plot_distribution(samples_four, color='red')
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Although both of these apple trees seem to also be normally distributed, tree three has a much higher variance.
#
# If you run our mean_tree_yield() function, you will find that tree three (blue distribution) has a higher mean yield.
#
# But let's say you need 5kg of apples today. Can you calculate which of the two trees (tree_three and tree_four) is most likely to yield you at least 5kg on any given day?
#
# Don't remember how to calculate a probability from a distribution? Check out this: https://mathworld.wolfram.com/DistributionFunction.html
#
# You will need to do two things:
# 1) Estimate the parameters of the distribution for each tree from the samples you collected. (You can use scipy.stats.norm)
# 2) Calculate the probability for each tree to yield at least 5kg (You will want to use the cumulative distribution function for this)
#
# The commonly used Python packages all have pretty decent online documentation. Don't intrinsically know how to use scipy.stats.norm? Nobody does. Check this:
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html

# %%
from scipy.stats import norm

# Use the same samples we collected above to make sure your answer matches ours.
np.random.seed(42)
samples_three = [forageBot.forage(tree_three) for i in range(500)]
samples_four = [forageBot.forage(tree_four) for i in range(500)]

# Caculate the mean and standard deviation for sample three
sample_three_mean = np.mean(samples_three)
sample_three_std = np.std(samples_three)

# Caculate the mean and standard deviation for sample four
sample_four_mean = np.mean(samples_four)
sample_four_std = np.std(samples_four)

#Caculate the cumulative distribution function
three_cdf = norm.cdf(5, loc=sample_three_mean, scale=sample_three_std)
four_cdf = norm.cdf(5, loc=np.mean(samples_four), scale=np.std(samples_four))

# Assign the probability that tree three yields more than 5kg of apples on any given day to ANSWER_PROB_TREE_THREE
ANSWER_PROB_TREE_THREE = 1-three_cdf
# Assign the probability that tree four yields more than 5kg of apples on any given day to ANSWER_PROB_TREE_FOUR
ANSWER_PROB_TREE_FOUR = 1-four_cdf



tests.Test_ExerciseTwo(ANSWER_PROB_TREE_THREE=ANSWER_PROB_TREE_THREE, ANSWER_PROB_TREE_FOUR=ANSWER_PROB_TREE_FOUR);
# Out:
# All tests passed

# %% [markdown]
# Now that we have figured out how to evaluate trees, let's explore a little and find some new ones.
# Your forage bot can also explore to find new foragable things in the forest. Run the function explore() a few times and see what you get.

# %%
discovery = forageBot.explore()
print(isinstance(discovery,Tree))
print(discovery)
print(forageBot.forage(forageBot.explore(), verbose=True));
# Out:
# False
# <scenario.forage_bot.BerryBush object at 0x0000019F2AA9B4F0>
# The robot collected 9.26kg of apples
# 9.257937973001253

# %% [markdown]
# The output you get might not be the most clear. <scenario.forage_bot.Tree object at 0x000002978E34B7D0> simply means that the function explore() returned an object of class Tree from the scenario.forage_bot module. <scenario.forage_bot.BerryBush object at 0x000001ECEFC7B040> is a different class, BerryBush, from the same module. Apparently, explore can return one of two different return types.
#
# So, as you can see, your robot will find new trees and berry bushes when exploring.

# %% [markdown]
# ## Final task bronze level
# Your final task for the bronze medal is to find a tree that will yield more than 8kg of apples on more than 75% of days.
# Use the explore function together with the functions you have created so far!
#
# Note: Trees have some attributes which of course you could theoretically look up directly by checking the scenario files, instead of estimating them from samples. But a solution which is based on this will NOT be accepted.
#
# Since the explore() method can result in both Tree or BerryBush, you will need to check whether you found a Tree. There are several ways in which this can be done, on of which is the built-in isinstance() function.

# %%
# Set a seed so that your solution works when we test it.
np.random.seed(42)
discovery_cdf=0 #set default probability

#Search for a new tree that fulfils the requirement
while (discovery_cdf<0.75): #while the probability is less than 75%
    discovery = forageBot.explore() #explore new tree/berrybush
    if isinstance(discovery,Tree): #check whether I found a tree
        sample_discovery = [forageBot.forage(discovery) for i in range(500)] #get 500 samples of the tree
        discovery_cdf = 1-norm.cdf(8, loc=np.mean(sample_discovery), scale=np.std(sample_discovery)) #caculate the probability that the tree yield more than 8kg of apples
print(discovery_cdf)
# Assign this tree here
BRONZE_MEDAL_TREE = discovery



tests.Test_ExerciseThree(BRONZE_MEDAL_TREE=BRONZE_MEDAL_TREE);
# Out:
# 0.9361753471694569
# All tests passed

# %% [markdown]
# ## Silver Level: Conditional Probabilities
# When solving the last task, you found not just trees, but also bushes. You had to ignore them while looking for a suitable tree, but now let's have a look at a berry bush!
# Run the cell below a few times.

# %%
bush_one = forageBot.pre_survey['bush_one']
forageBot.forage(bush_one, verbose=True);
# Out:
# The robot collected 1.99kg of berries

# %% [markdown]
# Just like the apple trees, the yield varies each day; however, for berries, the yield seems to vary even more strongly.
#
# Let's collect a few samples and then plot the distribution.

# %%
# Set random seed so output matches the expected output
np.random.seed(42)

# Collect from both trees
samples = [forageBot.forage(bush_one) for i in range(5000)]

# Plot distributions
plot_distribution(samples)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# That looks quite different from the apple trees!
#
# This appears to be a bimodal distribution. A common reason for bimodal distributions is that we might be measuring two different populations as one, or that our samples might be affected by a variable that we are not teking into account.
#
# Let's see if we can find an underlying explanation for this shape. One thing that might affect the performance of your ForageBot might be the weather. Let's try plotting samples from this berry bush depending on the current weather.
#
# You can check whether it is currently sunny or raining with forageBot.is_it_raining()
#
# Note that weather changes IMMEDIATELY AFTER each forage() or explore() action (or, strictly speaking, changes at the end of that function call). That means you must check the weather first, then go forage().

# %%
# Set random seed so output matches the expected output
np.random.seed(42)

samples_sunny = []
samples_rainy = []

for i in range(5000):
    if forageBot.is_it_raining():
        samples_rainy.append(forageBot.forage(bush_one))
    else:
        samples_sunny.append(forageBot.forage(bush_one))


# Plot distributions
plot_distribution(samples_sunny, color='blue')
plot_distribution(samples_rainy, color='red')
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# You should generate this image:
#
# <img src="resources/plot3.png" alt="Seperate distributions based on weather" width="200"/>
#
# This indeed looks like two separate distributions! Make sure to note whether your ForageBot collects more berries in sunny or rainy weather, it may come in handy later!
#
# Earlier, we tried to figure out which apple tree gives us the best chance of getting a certain amount of apples for making pie. Now it's time for a blueberry cobbler, so let's see if we can calculate the chance of collecting at least 2kg of berries. Let us first plot the CDF of these samples by running the cell below.

# %%
# Collecting again just as above
np.random.seed(42)
samples = [forageBot.forage(bush_one) for i in range(5000)]

# Generate the cumulative distribution function from our samples
sorted_samples = np.sort(samples)
probability = np.arange(len(samples)) / (len(samples) - 1)

# Plot the CDF:
sns.lineplot(x=sorted_samples, y=probability);

# %% [markdown]
# You should generate this image:
#
# <img src="resources/plot4.png" alt="" width="200"/>
#
# This plot shows us that there is visually a roughly 40% chance of getting a value below 2 from this distribution and thus a roughly 60% chance of getting at 2kg of berries or more.
#
# But we can get an even better estimate, if we take take the weather into account! Try creating the same plot, but split by weather.

# %%
# Collecting again just as above
np.random.seed(42)

# These samples should still be available, if not recollect them as above.
# samples_sunny = []
# samples_rainy = []

# Calculate the 2 PDFs for sunny and rainy weather here, using the code above.

#samples_sunny
sorted_samples_sunny = np.sort(samples_sunny)
probability_sunny = np.arange(len(samples_sunny)) / (len(samples_sunny) - 1)

#samples_rainy
sorted_samples_rainy= np.sort(samples_rainy)
probability_rainy = np.arange(len(samples_rainy)) / (len(samples_rainy) - 1)

# Plot the CDF:
sns.lineplot(x=sorted_samples_sunny, y=probability_sunny, color='blue')
sns.lineplot(x=sorted_samples_rainy, y=probability_rainy, color='red');

# %% [markdown]
# You should generate this image:
#
# <img src="resources/plot5.png" alt="" width="200"/>
#
# Looks like you are almost guaranteed 2kg of berries on a sunny day, but that on a rainy day you will rarely find so many.
#
# But if we want to plan ahead for whether we can bake a blueberry cobbler this week, we also need to know the probability of rain!
#
# We could collect some samples and then estimate the probability of rain, but I can also just tell you: Any day has a 40% chance of rain and is otherwise sunny.
#
# Now, with these probabilities, we can even make inferences on what the weather was like just from the amount of berries we collected. Let's say you programmed your BakeBot (sold separately) to make a blueberry cobbler any time the ForageBot returns with at least 2kg of berries. You've just come back from vacation, and there is a cobbler made yesterday waiting for you in the kitchen. What are the odds that it was raining yesterday?
#
# You know that $P(rain)=0.4$
# Now calculate the probability to find a cobbler depending on whether or not it rained, that is $P(cobbler|sunny)$ and $P(cobbler|rainy)$

# %%
# Here are the precise distributions for bush_one:
bush_one_sunny_dist = norm(loc=3, scale=0.5)
bush_one_rainy_dist = norm(loc=1.5, scale=0.5)

# Calculate the precise probability of getting at least 2kg of berries from bush_one given either weather (using the cdf)
sunny_cdf = 1-norm.cdf(2, loc=3, scale=0.5)
rainy_cdf = 1-norm.cdf(2, loc=1.5, scale=0.5)

ANSWER_PROB_IF_SUNNY = sunny_cdf
ANSWER_PROB_IF_RAINY = rainy_cdf

print(sunny_cdf,rainy_cdf)
# Out:
# 0.9772498680518208 0.15865525393145707

# %% [markdown]
# Now calculate the probability that it has rained, given that you know enough berries have been collected, that is $P(rainy|cobbler)$
#
# You can use Bayes' rule: $$P(B|A)={\frac {P(A|B)*P(B)}{P(A)}}$$
#
# Remember that the overall probability of event A can be rewritten as: $$P(A)={P(A|B)P(B) + P(A|\neg B)P(\neg B)}$$
#
# Hint: If you are lost, try entering what you know here: https://www.omnicalculator.com/statistics/conditional-probability

# %%
# Calculate the probability getting enough berries ignoring the whether condition
prob_berry = 1-norm.cdf(2, loc=np.mean(samples), scale=np.std(samples))

# Calculate the probability that it has rained
prob = rainy_cdf*0.4/prob_berry

# Assign the probability that it has rained below
ANSWER_HAS_IT_RAINED = prob

print(prob)
# Out:
# 0.09500870685036025

# %% [markdown]
# ## Gold Level: Explore and Exploit
# The gold level is a single challenge: Make as much money from your ForageBot as possible in 5000 days.
#
# There are a few new rules for this, which will be briefoly explained.
#
# First, every time to explore or forage a day passes, which will be counted. The days can be reset with ForageBot.reset_days() which you MUST call in the first AND ONLY THE FIRST line of your solution.

# %%
ForageBot.reset_days()
forageBot = ForageBot()
day = forageBot.what_day_is_it()
print(f'It is day {day}')
explore = forageBot.explore()
print(explore)
day = forageBot.what_day_is_it()
print(f'It is day {day}')
forageBot.forage(ForageBot.pre_survey['tree_one'])
day = forageBot.what_day_is_it()
print(f'It is day {day}')
# Out:
# It is day 0
# <scenario.forage_bot.Tree object at 0x0000019F2C0F1460>
# It is day 1
# It is day 2

# %% [markdown]
# Things you forage are stored in your inventory. Apples and berries last three days and then expire (disappear from the inventory).
# Items in the inventory are stored as tuples: (Type of fruit: str, amount: float, days until it spoils: int)

# %%
forageBot = ForageBot()
print(forageBot.inventory)
print(forageBot.forage(ForageBot.pre_survey['tree_one']))
print(forageBot.inventory)
forageBot.forage(ForageBot.pre_survey['tree_one'])
print(forageBot.inventory)
forageBot.forage(ForageBot.pre_survey['bush_one'])
print(forageBot.inventory)
forageBot.forage(ForageBot.pre_survey['bush_one'])
print(forageBot.inventory)
# Out:
# []
# 5.141658432216612
# [('apples', 5.141658432216612, 3)]
# [('apples', 5.141658432216612, 2), ('apples', 2.1147696543084056, 3)]
# [('apples', 5.141658432216612, 1), ('apples', 2.1147696543084056, 2), ('berries', 2.7939057597639247, 3)]
# [('apples', 2.1147696543084056, 1), ('berries', 2.7939057597639247, 2), ('berries', 1.616547619529872, 3)]

# %% [markdown]
# You can now sell what you foraged! You can only sell all of your inventory at once, not individual items.
# Apples are usually worth 1 euro per kilo.
# Berries are usually worth 3 euros per kilo.
# Prices can however vary by weekday. Apples sell better on Tuesday and Wednesday. Berries sell better on the weekend. The first day is a Monday.

# %%
forageBot = ForageBot()
forageBot.forage(ForageBot.pre_survey['tree_one'])
forageBot.sell(verbose=True)
forageBot.forage(ForageBot.pre_survey['tree_one'])
forageBot.forage(ForageBot.pre_survey['bush_one'])
forageBot.sell(verbose=True);
# Out:
# You earned €3.12 from selling your inventory. Your total is now €3.12
# You earned €24.66 from selling your inventory. Your total is now €27.78

# %% [markdown]
# Now try to find the optimal strategy for making as much money in 5000 days as possible!
#
# - You may call forageBot.explore() and forageBot.forage() a combined total of 5000 times. Weather can change every day, and the day passes immediately after exploring or foraging.
# - You may sell() as often as you want. Take weekday prices into account. The first day is Monday.
# - ForageBot.reset_days() MUST be called in the first AND ONLY THE FIRST line of your solution.
# - You MAY NOT use any of the pre_survey trees and bushes, nor may you use trees or bushes you have discovered previously. You can only forage things you have found within the 5000 days.
# - You MAY NOT directly modify any things you can find in forage_bot.py, such as manually creating trees or messing with sales prices, etc.
# - You MAY NOT use additional imports in the solution you submit. You may use libraries imported at the beginning, such as numpy.
# - You may hardcode parameters that you may have discovered while using additional libraries such as sklearn, as long as those are no longer imported and required for the solution.
# - We may test your solution with a different random seed if the solution seems to rely on something that can only happen in the chosen seed. In that case, you will receive gold if your solution passes at least a quarter of all seeds.
#
# You will receive the gold medal if you manage to earn more than €100.000,00!

# %%
ForageBot.reset_days(limit=5000)
forageBot = ForageBot()

def average(list):
    avr = sum(list) / len(list)
    return avr
tree = None
berry = None
tree_sunny = [0]
tree_rainy = [0]
berry_sunny = [0]
berry_rainy = [0]
best_tree = 0
best_bush = 0
while best_tree == 0 or best_bush == 0:
    explore = forageBot.explore()
    if day % 7 == [1,2,5,6]:
        forageBot.sell(verbose=True)
    if isinstance(explore,Tree) and (average(tree_sunny)<6.5 or average(tree_rainy)<4.7):
        new_amount = forageBot.forage(explore)
        day = forageBot.what_day_is_it()
        if forageBot.is_it_raining():
                    if average(tree_rainy)<new_amount:
                        tree = explore
                        # tree_sunny = [0]
                        tree_rainy = [0]
                        tree_rainy.append(new_amount)
        else:
                    if average(tree_sunny)<new_amount:
                        tree = explore
                        tree_sunny = [0]
                        # tree_rainy = [0]  
                        tree_sunny.append(new_amount)   
    if isinstance(explore,Tree) and (average(tree_sunny)>=6.5 or average(tree_rainy)>=4.7):
        best_tree +=1
    if isinstance(explore,BerryBush) and (average(berry_sunny)<4 or average(berry_rainy)<2.25):
            new_amount = forageBot.forage(explore)
            if forageBot.is_it_raining():
                    if average(berry_rainy)<new_amount:
                        berry = explore
                        # berry_sunny = [0]
                        berry_rainy = [0]
                        berry_rainy.append(new_amount)
            else:
                    if average(berry_sunny)<new_amount:
                        berry = explore
                        berry_sunny = [0]
                        # berry_rainy = [0]  
                        berry_sunny.append(new_amount)  
    if isinstance(explore,BerryBush) and (average(berry_sunny)>=4 or average(berry_rainy)>=2.25):
                     best_bush +=1

day = forageBot.what_day_is_it()  
print(f'It is day {day}')    
print("Good trees")
while day <5000:
    day = forageBot.what_day_is_it()   
    if day % 7 == 0:
        if forageBot.is_it_raining():
            tree_rainy.append(forageBot.forage(tree))
        else:
            tree_sunny.append(forageBot.forage(tree)) 
    if day % 7 in [1,6]:
        forageBot.sell(verbose=True)
        if forageBot.is_it_raining():
            tree_rainy.append(forageBot.forage(tree))
        else:
            tree_sunny.append(forageBot.forage(tree))  
    if day % 7 in [3,4]:
        if forageBot.is_it_raining():
            berry_rainy.append(forageBot.forage(berry))
        else:
            berry_sunny.append(forageBot.forage(berry)) 
    if day % 7 in [2,5]:
        forageBot.sell(verbose=True)
        if forageBot.is_it_raining():
            berry_rainy.append(forageBot.forage(berry))
        else:
            berry_sunny.append(forageBot.forage(berry))
# Out:
# It is day 562
# Good trees
# You earned €47.36 from selling your inventory. Your total is now €47.36
# You earned €35.80 from selling your inventory. Your total is now €83.16
# You earned €25.92 from selling your inventory. Your total is now €109.08
# You earned €74.13 from selling your inventory. Your total is now €183.21
# You earned €32.08 from selling your inventory. Your total is now €215.29
# You earned €27.22 from selling your inventory. Your total is now €242.51
# You earned €9.82 from selling your inventory. Your total is now €252.33
# You earned €60.75 from selling your inventory. Your total is now €313.09
# You earned €34.13 from selling your inventory. Your total is now €347.22
# You earned €17.72 from selling your inventory. Your total is now €364.94
# You earned €6.12 from selling your inventory. Your total is now €371.06
# You earned €85.08 from selling your inventory. Your total is now €456.14
# You earned €34.67 from selling your inventory. Your total is now €490.81
# You earned €34.56 from selling your inventory. Your total is now €525.37
# You earned €12.93 from selling your inventory. Your total is now €538.30
# You earned €74.21 from selling your inventory. Your total is now €612.51
# You earned €38.30 from selling your inventory. Your total is now €650.80
# You earned €61.59 from selling your inventory. Your total is now €712.40
# You earned €19.63 from selling your inventory. Your total is now €732.03
# You earned €70.55 from selling your inventory. Your total is now €802.58
# You earned €44.15 from selling your inventory. Your total is now €846.73
# You earned €26.06 from selling your inventory. Your total is now €872.79
# You earned €6.22 from selling your inventory. Your total is now €879.01
# You earned €79.71 from selling your inventory. Your total is now €958.71
# You earned €33.51 from selling your inventory. Your total is now €992.23
# You earned €38.04 from selling your inventory. Your total is now €1030.27
# You earned €13.02 from selling your inventory. Your total is now €1043.29
# You earned €74.87 from selling your inventory. Your total is now €1118.15
# You earned €40.48 from selling your inventory. Your total is now €1158.63
# You earned €18.48 from selling your inventory. Your total is now €1177.11
# You earned €13.78 from selling your inventory. Your total is now €1190.89
# You earned €90.84 from selling your inventory. Your total is now €1281.74
# You earned €35.87 from selling your inventory. Your total is now €1317.61
# You earned €12.66 from selling your inventory. Your total is now €1330.27
# You earned €9.09 from selling your inventory. Your total is now €1339.36
# You earned €63.97 from selling your inventory. Your total is now €1403.33
# You earned €18.44 from selling your inventory. Your total is now €1421.77
# You earned €37.98 from selling your inventory. Your total is now €1459.75
# You earned €9.22 from selling your inventory. Your total is now €1468.97
# You earned €74.68 from selling your inventory. Your total is now €1543.65
# You earned €46.85 from selling your inventory. Your total is now €1590.50
# You earned €45.45 from selling your inventory. Your total is now €1635.95
# You earned €8.66 from selling your inventory. Your total is now €1644.61
# You earned €48.09 from selling your inventory. Your total is now €1692.70
# You earned €32.20 from selling your inventory. Your total is now €1724.90
# You earned €33.09 from selling your inventory. Your total is now €1757.99
# You earned €4.71 from selling your inventory. Your total is now €1762.70
# You earned €57.15 from selling your inventory. Your total is now €1819.85
# You earned €23.36 from selling your inventory. Your total is now €1843.22
# You earned €43.67 from selling your inventory. Your total is now €1886.89
# You earned €12.64 from selling your inventory. Your total is now €1899.52
# You earned €78.06 from selling your inventory. Your total is now €1977.58
# You earned €33.12 from selling your inventory. Your total is now €2010.70
# You earned €21.55 from selling your inventory. Your total is now €2032.26
# You earned €8.56 from selling your inventory. Your total is now €2040.82
# You earned €57.76 from selling your inventory. Your total is now €2098.58
# You earned €44.39 from selling your inventory. Your total is now €2142.97
# You earned €27.45 from selling your inventory. Your total is now €2170.41
# You earned €8.63 from selling your inventory. Your total is now €2179.05
# You earned €59.46 from selling your inventory. Your total is now €2238.50
# You earned €28.68 from selling your inventory. Your total is now €2267.18
# You earned €28.11 from selling your inventory. Your total is now €2295.29
# You earned €3.16 from selling your inventory. Your total is now €2298.44
# You earned €64.83 from selling your inventory. Your total is now €2363.28
# You earned €38.11 from selling your inventory. Your total is now €2401.39
# You earned €31.06 from selling your inventory. Your total is now €2432.46
# You earned €20.16 from selling your inventory. Your total is now €2452.61
# You earned €51.36 from selling your inventory. Your total is now €2503.97
# You earned €25.05 from selling your inventory. Your total is now €2529.02
# You earned €22.94 from selling your inventory. Your total is now €2551.96
# You earned €9.59 from selling your inventory. Your total is now €2561.55
# You earned €74.80 from selling your inventory. Your total is now €2636.35
# You earned €29.68 from selling your inventory. Your total is now €2666.03
# You earned €36.92 from selling your inventory. Your total is now €2702.95
# You earned €5.25 from selling your inventory. Your total is now €2708.20
# You earned €69.10 from selling your inventory. Your total is now €2777.30
# You earned €32.44 from selling your inventory. Your total is now €2809.74
# You earned €32.24 from selling your inventory. Your total is now €2841.98
# You earned €8.55 from selling your inventory. Your total is now €2850.53
# You earned €75.35 from selling your inventory. Your total is now €2925.88
# You earned €31.89 from selling your inventory. Your total is now €2957.78
# You earned €27.53 from selling your inventory. Your total is now €2985.31
# You earned €20.14 from selling your inventory. Your total is now €3005.45
# You earned €47.19 from selling your inventory. Your total is now €3052.63
# You earned €29.68 from selling your inventory. Your total is now €3082.31
# You earned €18.73 from selling your inventory. Your total is now €3101.04
# You earned €5.31 from selling your inventory. Your total is now €3106.34
# You earned €61.88 from selling your inventory. Your total is now €3168.23
# You earned €29.24 from selling your inventory. Your total is now €3197.47
# You earned €14.23 from selling your inventory. Your total is now €3211.70
# You earned €21.11 from selling your inventory. Your total is now €3232.81
# You earned €60.15 from selling your inventory. Your total is now €3292.96
# You earned €24.68 from selling your inventory. Your total is now €3317.64
# You earned €59.28 from selling your inventory. Your total is now €3376.92
# You earned €10.57 from selling your inventory. Your total is now €3387.48
# You earned €55.82 from selling your inventory. Your total is now €3443.30
# You earned €33.11 from selling your inventory. Your total is now €3476.41
# You earned €33.89 from selling your inventory. Your total is now €3510.30
# You earned €13.30 from selling your inventory. Your total is now €3523.61
# You earned €66.48 from selling your inventory. Your total is now €3590.09
# You earned €43.97 from selling your inventory. Your total is now €3634.06
# You earned €40.79 from selling your inventory. Your total is now €3674.85
# You earned €6.82 from selling your inventory. Your total is now €3681.67
# You earned €75.87 from selling your inventory. Your total is now €3757.54
# You earned €21.79 from selling your inventory. Your total is now €3779.34
# You earned €42.70 from selling your inventory. Your total is now €3822.04
# You earned €3.53 from selling your inventory. Your total is now €3825.57
# You earned €82.30 from selling your inventory. Your total is now €3907.87
# You earned €18.13 from selling your inventory. Your total is now €3926.01
# You earned €56.34 from selling your inventory. Your total is now €3982.35
# You earned €11.61 from selling your inventory. Your total is now €3993.95
# You earned €52.95 from selling your inventory. Your total is now €4046.90
# You earned €28.32 from selling your inventory. Your total is now €4075.22
# You earned €37.50 from selling your inventory. Your total is now €4112.73
# You earned €17.49 from selling your inventory. Your total is now €4130.21
# You earned €75.10 from selling your inventory. Your total is now €4205.32
# You earned €32.98 from selling your inventory. Your total is now €4238.30
# You earned €23.33 from selling your inventory. Your total is now €4261.64
# You earned €11.61 from selling your inventory. Your total is now €4273.25
# You earned €51.19 from selling your inventory. Your total is now €4324.44
# You earned €29.91 from selling your inventory. Your total is now €4354.35
# You earned €37.13 from selling your inventory. Your total is now €4391.48
# You earned €8.10 from selling your inventory. Your total is now €4399.58
# You earned €53.60 from selling your inventory. Your total is now €4453.18
# You earned €24.97 from selling your inventory. Your total is now €4478.16
# You earned €38.91 from selling your inventory. Your total is now €4517.06
# You earned €11.22 from selling your inventory. Your total is now €4528.28
# You earned €57.14 from selling your inventory. Your total is now €4585.42
# You earned €33.38 from selling your inventory. Your total is now €4618.79
# You earned €32.83 from selling your inventory. Your total is now €4651.62
# You earned €9.76 from selling your inventory. Your total is now €4661.38
# You earned €44.26 from selling your inventory. Your total is now €4705.64
# You earned €38.91 from selling your inventory. Your total is now €4744.55
# You earned €24.23 from selling your inventory. Your total is now €4768.77
# You earned €7.70 from selling your inventory. Your total is now €4776.47
# You earned €63.66 from selling your inventory. Your total is now €4840.13
# You earned €40.98 from selling your inventory. Your total is now €4881.11
# You earned €28.08 from selling your inventory. Your total is now €4909.19
# You earned €4.44 from selling your inventory. Your total is now €4913.63
# You earned €66.52 from selling your inventory. Your total is now €4980.15
# You earned €22.38 from selling your inventory. Your total is now €5002.54
# You earned €45.38 from selling your inventory. Your total is now €5047.92
# You earned €28.62 from selling your inventory. Your total is now €5076.54
# You earned €60.07 from selling your inventory. Your total is now €5136.60
# You earned €31.40 from selling your inventory. Your total is now €5168.00
# You earned €48.19 from selling your inventory. Your total is now €5216.19
# You earned €5.10 from selling your inventory. Your total is now €5221.28
# You earned €47.20 from selling your inventory. Your total is now €5268.49
# You earned €28.22 from selling your inventory. Your total is now €5296.71
# You earned €33.68 from selling your inventory. Your total is now €5330.39
# You earned €12.11 from selling your inventory. Your total is now €5342.49
# You earned €56.68 from selling your inventory. Your total is now €5399.17
# You earned €36.03 from selling your inventory. Your total is now €5435.20
# You earned €23.54 from selling your inventory. Your total is now €5458.74
# You earned €0.00 from selling your inventory. Your total is now €5458.74
# You earned €72.47 from selling your inventory. Your total is now €5531.22
# You earned €40.43 from selling your inventory. Your total is now €5571.65
# You earned €19.11 from selling your inventory. Your total is now €5590.76
# You earned €10.67 from selling your inventory. Your total is now €5601.43
# You earned €60.02 from selling your inventory. Your total is now €5661.45
# You earned €34.49 from selling your inventory. Your total is now €5695.94
# You earned €27.88 from selling your inventory. Your total is now €5723.82
# You earned €19.23 from selling your inventory. Your total is now €5743.05
# You earned €65.75 from selling your inventory. Your total is now €5808.79
# You earned €46.43 from selling your inventory. Your total is now €5855.22
# You earned €24.41 from selling your inventory. Your total is now €5879.63
# You earned €15.04 from selling your inventory. Your total is now €5894.66
# You earned €78.87 from selling your inventory. Your total is now €5973.54
# You earned €24.64 from selling your inventory. Your total is now €5998.18
# You earned €42.97 from selling your inventory. Your total is now €6041.14
# You earned €13.17 from selling your inventory. Your total is now €6054.32
# You earned €64.02 from selling your inventory. Your total is now €6118.34
# You earned €38.02 from selling your inventory. Your total is now €6156.36
# You earned €19.12 from selling your inventory. Your total is now €6175.48
# You earned €19.99 from selling your inventory. Your total is now €6195.47
# You earned €68.18 from selling your inventory. Your total is now €6263.66
# You earned €26.17 from selling your inventory. Your total is now €6289.82
# You earned €35.24 from selling your inventory. Your total is now €6325.06
# You earned €8.63 from selling your inventory. Your total is now €6333.70
# You earned €49.88 from selling your inventory. Your total is now €6383.57
# You earned €37.36 from selling your inventory. Your total is now €6420.93
# You earned €58.62 from selling your inventory. Your total is now €6479.55
# You earned €15.64 from selling your inventory. Your total is now €6495.20
# You earned €55.99 from selling your inventory. Your total is now €6551.18
# You earned €21.82 from selling your inventory. Your total is now €6573.01
# You earned €19.63 from selling your inventory. Your total is now €6592.64
# You earned €1.30 from selling your inventory. Your total is now €6593.95
# You earned €44.52 from selling your inventory. Your total is now €6638.47
# You earned €29.91 from selling your inventory. Your total is now €6668.38
# You earned €33.98 from selling your inventory. Your total is now €6702.36
# You earned €22.63 from selling your inventory. Your total is now €6724.99
# You earned €65.19 from selling your inventory. Your total is now €6790.18
# You earned €41.81 from selling your inventory. Your total is now €6831.99
# You earned €36.03 from selling your inventory. Your total is now €6868.02
# You earned €17.61 from selling your inventory. Your total is now €6885.63
# You earned €72.36 from selling your inventory. Your total is now €6957.99
# You earned €26.59 from selling your inventory. Your total is now €6984.58
# You earned €26.56 from selling your inventory. Your total is now €7011.15
# You earned €5.83 from selling your inventory. Your total is now €7016.98
# You earned €42.79 from selling your inventory. Your total is now €7059.77
# You earned €18.84 from selling your inventory. Your total is now €7078.61
# You earned €35.03 from selling your inventory. Your total is now €7113.64
# You earned €12.09 from selling your inventory. Your total is now €7125.73
# You earned €72.75 from selling your inventory. Your total is now €7198.48
# You earned €36.76 from selling your inventory. Your total is now €7235.24
# You earned €24.50 from selling your inventory. Your total is now €7259.74
# You earned €13.03 from selling your inventory. Your total is now €7272.77
# You earned €60.43 from selling your inventory. Your total is now €7333.20
# You earned €37.00 from selling your inventory. Your total is now €7370.20
# You earned €36.15 from selling your inventory. Your total is now €7406.36
# You earned €3.22 from selling your inventory. Your total is now €7409.58
# You earned €72.59 from selling your inventory. Your total is now €7482.16
# You earned €36.02 from selling your inventory. Your total is now €7518.18
# You earned €10.41 from selling your inventory. Your total is now €7528.59
# You earned €14.79 from selling your inventory. Your total is now €7543.38
# You earned €72.23 from selling your inventory. Your total is now €7615.61
# You earned €19.75 from selling your inventory. Your total is now €7635.36
# You earned €49.17 from selling your inventory. Your total is now €7684.54
# You earned €6.73 from selling your inventory. Your total is now €7691.27
# You earned €55.54 from selling your inventory. Your total is now €7746.81
# You earned €32.03 from selling your inventory. Your total is now €7778.84
# You earned €36.58 from selling your inventory. Your total is now €7815.42
# You earned €8.14 from selling your inventory. Your total is now €7823.56
# You earned €56.31 from selling your inventory. Your total is now €7879.86
# You earned €42.47 from selling your inventory. Your total is now €7922.33
# You earned €17.11 from selling your inventory. Your total is now €7939.44
# You earned €7.60 from selling your inventory. Your total is now €7947.04
# You earned €44.80 from selling your inventory. Your total is now €7991.83
# You earned €26.38 from selling your inventory. Your total is now €8018.22
# You earned €24.09 from selling your inventory. Your total is now €8042.31
# You earned €12.05 from selling your inventory. Your total is now €8054.36
# You earned €60.03 from selling your inventory. Your total is now €8114.38
# You earned €24.53 from selling your inventory. Your total is now €8138.91
# You earned €28.42 from selling your inventory. Your total is now €8167.34
# You earned €16.67 from selling your inventory. Your total is now €8184.00
# You earned €77.19 from selling your inventory. Your total is now €8261.19
# You earned €23.61 from selling your inventory. Your total is now €8284.81
# You earned €23.84 from selling your inventory. Your total is now €8308.65
# You earned €11.09 from selling your inventory. Your total is now €8319.74
# You earned €82.76 from selling your inventory. Your total is now €8402.50
# You earned €15.33 from selling your inventory. Your total is now €8417.83
# You earned €24.62 from selling your inventory. Your total is now €8442.45
# You earned €2.84 from selling your inventory. Your total is now €8445.29
# You earned €63.73 from selling your inventory. Your total is now €8509.02
# You earned €22.29 from selling your inventory. Your total is now €8531.30
# You earned €32.03 from selling your inventory. Your total is now €8563.33
# You earned €13.83 from selling your inventory. Your total is now €8577.17
# You earned €61.32 from selling your inventory. Your total is now €8638.48
# You earned €41.76 from selling your inventory. Your total is now €8680.24
# You earned €12.36 from selling your inventory. Your total is now €8692.60
# You earned €7.90 from selling your inventory. Your total is now €8700.50
# You earned €62.97 from selling your inventory. Your total is now €8763.47
# You earned €25.39 from selling your inventory. Your total is now €8788.85
# You earned €22.58 from selling your inventory. Your total is now €8811.43
# You earned €13.53 from selling your inventory. Your total is now €8824.96
# You earned €71.10 from selling your inventory. Your total is now €8896.06
# You earned €35.90 from selling your inventory. Your total is now €8931.96
# You earned €39.58 from selling your inventory. Your total is now €8971.54
# You earned €14.56 from selling your inventory. Your total is now €8986.10
# You earned €70.57 from selling your inventory. Your total is now €9056.67
# You earned €43.76 from selling your inventory. Your total is now €9100.43
# You earned €31.52 from selling your inventory. Your total is now €9131.95
# You earned €15.88 from selling your inventory. Your total is now €9147.83
# You earned €74.63 from selling your inventory. Your total is now €9222.46
# You earned €35.03 from selling your inventory. Your total is now €9257.49
# You earned €49.02 from selling your inventory. Your total is now €9306.51
# You earned €14.49 from selling your inventory. Your total is now €9321.01
# You earned €62.34 from selling your inventory. Your total is now €9383.35
# You earned €35.60 from selling your inventory. Your total is now €9418.95
# You earned €48.86 from selling your inventory. Your total is now €9467.81
# You earned €9.92 from selling your inventory. Your total is now €9477.73
# You earned €45.98 from selling your inventory. Your total is now €9523.70
# You earned €19.70 from selling your inventory. Your total is now €9543.40
# You earned €24.39 from selling your inventory. Your total is now €9567.79
# You earned €6.67 from selling your inventory. Your total is now €9574.46
# You earned €53.34 from selling your inventory. Your total is now €9627.80
# You earned €28.77 from selling your inventory. Your total is now €9656.57
# You earned €22.58 from selling your inventory. Your total is now €9679.15
# You earned €8.50 from selling your inventory. Your total is now €9687.65
# You earned €40.42 from selling your inventory. Your total is now €9728.07
# You earned €33.35 from selling your inventory. Your total is now €9761.42
# You earned €27.34 from selling your inventory. Your total is now €9788.76
# You earned €10.00 from selling your inventory. Your total is now €9798.76
# You earned €54.61 from selling your inventory. Your total is now €9853.37
# You earned €20.72 from selling your inventory. Your total is now €9874.08
# You earned €31.83 from selling your inventory. Your total is now €9905.92
# You earned €5.11 from selling your inventory. Your total is now €9911.03
# You earned €59.18 from selling your inventory. Your total is now €9970.21
# You earned €29.24 from selling your inventory. Your total is now €9999.45
# You earned €14.52 from selling your inventory. Your total is now €10013.97
# You earned €0.00 from selling your inventory. Your total is now €10013.97
# You earned €71.93 from selling your inventory. Your total is now €10085.90
# You earned €23.14 from selling your inventory. Your total is now €10109.04
# You earned €23.45 from selling your inventory. Your total is now €10132.49
# You earned €14.48 from selling your inventory. Your total is now €10146.97
# You earned €55.33 from selling your inventory. Your total is now €10202.30
# You earned €33.41 from selling your inventory. Your total is now €10235.71
# You earned €30.01 from selling your inventory. Your total is now €10265.72
# You earned €3.84 from selling your inventory. Your total is now €10269.56
# You earned €62.49 from selling your inventory. Your total is now €10332.05
# You earned €24.98 from selling your inventory. Your total is now €10357.03
# You earned €42.49 from selling your inventory. Your total is now €10399.52
# You earned €4.12 from selling your inventory. Your total is now €10403.63
# You earned €55.11 from selling your inventory. Your total is now €10458.74
# You earned €27.45 from selling your inventory. Your total is now €10486.19
# You earned €28.25 from selling your inventory. Your total is now €10514.45
# You earned €16.41 from selling your inventory. Your total is now €10530.86
# You earned €59.14 from selling your inventory. Your total is now €10590.00
# You earned €34.25 from selling your inventory. Your total is now €10624.25
# You earned €23.98 from selling your inventory. Your total is now €10648.23
# You earned €9.95 from selling your inventory. Your total is now €10658.18
# You earned €54.59 from selling your inventory. Your total is now €10712.77
# You earned €36.16 from selling your inventory. Your total is now €10748.92
# You earned €45.26 from selling your inventory. Your total is now €10794.19
# You earned €9.91 from selling your inventory. Your total is now €10804.10
# You earned €64.39 from selling your inventory. Your total is now €10868.49
# You earned €32.78 from selling your inventory. Your total is now €10901.28
# You earned €23.22 from selling your inventory. Your total is now €10924.49
# You earned €13.65 from selling your inventory. Your total is now €10938.14
# You earned €73.34 from selling your inventory. Your total is now €11011.48
# You earned €29.22 from selling your inventory. Your total is now €11040.70
# You earned €36.83 from selling your inventory. Your total is now €11077.54
# You earned €10.07 from selling your inventory. Your total is now €11087.61
# You earned €52.79 from selling your inventory. Your total is now €11140.40
# You earned €31.69 from selling your inventory. Your total is now €11172.09
# You earned €27.89 from selling your inventory. Your total is now €11199.99
# You earned €5.57 from selling your inventory. Your total is now €11205.56
# You earned €59.73 from selling your inventory. Your total is now €11265.29
# You earned €30.93 from selling your inventory. Your total is now €11296.22
# You earned €45.93 from selling your inventory. Your total is now €11342.15
# You earned €15.25 from selling your inventory. Your total is now €11357.40
# You earned €64.35 from selling your inventory. Your total is now €11421.75
# You earned €23.47 from selling your inventory. Your total is now €11445.22
# You earned €18.56 from selling your inventory. Your total is now €11463.78
# You earned €3.93 from selling your inventory. Your total is now €11467.70
# You earned €82.48 from selling your inventory. Your total is now €11550.19
# You earned €27.13 from selling your inventory. Your total is now €11577.32
# You earned €48.00 from selling your inventory. Your total is now €11625.32
# You earned €11.98 from selling your inventory. Your total is now €11637.31
# You earned €65.95 from selling your inventory. Your total is now €11703.26
# You earned €37.52 from selling your inventory. Your total is now €11740.78
# You earned €39.85 from selling your inventory. Your total is now €11780.63
# You earned €11.05 from selling your inventory. Your total is now €11791.68
# You earned €65.89 from selling your inventory. Your total is now €11857.57
# You earned €36.94 from selling your inventory. Your total is now €11894.51
# You earned €41.00 from selling your inventory. Your total is now €11935.51
# You earned €9.34 from selling your inventory. Your total is now €11944.84
# You earned €63.46 from selling your inventory. Your total is now €12008.30
# You earned €27.21 from selling your inventory. Your total is now €12035.51
# You earned €31.75 from selling your inventory. Your total is now €12067.26
# You earned €16.70 from selling your inventory. Your total is now €12083.96
# You earned €44.58 from selling your inventory. Your total is now €12128.55
# You earned €25.72 from selling your inventory. Your total is now €12154.26
# You earned €47.36 from selling your inventory. Your total is now €12201.63
# You earned €12.83 from selling your inventory. Your total is now €12214.46
# You earned €54.59 from selling your inventory. Your total is now €12269.05
# You earned €47.36 from selling your inventory. Your total is now €12316.41
# You earned €28.25 from selling your inventory. Your total is now €12344.66
# You earned €6.32 from selling your inventory. Your total is now €12350.98
# You earned €64.53 from selling your inventory. Your total is now €12415.52
# You earned €27.90 from selling your inventory. Your total is now €12443.42
# You earned €26.10 from selling your inventory. Your total is now €12469.52
# You earned €16.84 from selling your inventory. Your total is now €12486.36
# You earned €76.27 from selling your inventory. Your total is now €12562.63
# You earned €36.76 from selling your inventory. Your total is now €12599.39
# You earned €33.86 from selling your inventory. Your total is now €12633.25
# You earned €10.33 from selling your inventory. Your total is now €12643.58
# You earned €70.21 from selling your inventory. Your total is now €12713.80
# You earned €27.73 from selling your inventory. Your total is now €12741.52
# You earned €40.16 from selling your inventory. Your total is now €12781.69
# You earned €0.97 from selling your inventory. Your total is now €12782.66
# You earned €65.23 from selling your inventory. Your total is now €12847.89
# You earned €23.89 from selling your inventory. Your total is now €12871.78
# You earned €37.25 from selling your inventory. Your total is now €12909.03
# You earned €13.25 from selling your inventory. Your total is now €12922.28
# You earned €61.77 from selling your inventory. Your total is now €12984.05
# You earned €33.67 from selling your inventory. Your total is now €13017.72
# You earned €25.87 from selling your inventory. Your total is now €13043.59
# You earned €2.11 from selling your inventory. Your total is now €13045.70
# You earned €64.20 from selling your inventory. Your total is now €13109.90
# You earned €31.93 from selling your inventory. Your total is now €13141.83
# You earned €38.30 from selling your inventory. Your total is now €13180.13
# You earned €22.79 from selling your inventory. Your total is now €13202.92
# You earned €53.91 from selling your inventory. Your total is now €13256.83
# You earned €29.84 from selling your inventory. Your total is now €13286.67
# You earned €38.99 from selling your inventory. Your total is now €13325.66
# You earned €16.43 from selling your inventory. Your total is now €13342.09
# You earned €64.69 from selling your inventory. Your total is now €13406.78
# You earned €20.55 from selling your inventory. Your total is now €13427.34
# You earned €40.11 from selling your inventory. Your total is now €13467.45
# You earned €7.65 from selling your inventory. Your total is now €13475.10
# You earned €57.00 from selling your inventory. Your total is now €13532.10
# You earned €32.22 from selling your inventory. Your total is now €13564.32
# You earned €31.83 from selling your inventory. Your total is now €13596.15
# You earned €9.46 from selling your inventory. Your total is now €13605.61
# You earned €49.01 from selling your inventory. Your total is now €13654.62
# You earned €14.56 from selling your inventory. Your total is now €13669.18
# You earned €45.55 from selling your inventory. Your total is now €13714.73
# You earned €4.80 from selling your inventory. Your total is now €13719.53
# You earned €60.08 from selling your inventory. Your total is now €13779.61
# You earned €47.60 from selling your inventory. Your total is now €13827.21
# You earned €21.95 from selling your inventory. Your total is now €13849.16
# You earned €1.57 from selling your inventory. Your total is now €13850.72
# You earned €55.17 from selling your inventory. Your total is now €13905.89
# You earned €21.05 from selling your inventory. Your total is now €13926.94
# You earned €30.79 from selling your inventory. Your total is now €13957.72
# You earned €15.26 from selling your inventory. Your total is now €13972.98
# You earned €76.51 from selling your inventory. Your total is now €14049.49
# You earned €22.65 from selling your inventory. Your total is now €14072.14
# You earned €37.64 from selling your inventory. Your total is now €14109.78
# You earned €0.00 from selling your inventory. Your total is now €14109.78
# You earned €46.01 from selling your inventory. Your total is now €14155.79
# You earned €27.02 from selling your inventory. Your total is now €14182.82
# You earned €45.23 from selling your inventory. Your total is now €14228.04
# You earned €9.39 from selling your inventory. Your total is now €14237.43
# You earned €52.36 from selling your inventory. Your total is now €14289.79
# You earned €20.45 from selling your inventory. Your total is now €14310.24
# You earned €15.25 from selling your inventory. Your total is now €14325.49
# You earned €4.09 from selling your inventory. Your total is now €14329.58
# You earned €51.60 from selling your inventory. Your total is now €14381.18
# You earned €37.22 from selling your inventory. Your total is now €14418.40
# You earned €40.81 from selling your inventory. Your total is now €14459.21
# You earned €0.00 from selling your inventory. Your total is now €14459.21
# You earned €63.15 from selling your inventory. Your total is now €14522.35
# You earned €26.91 from selling your inventory. Your total is now €14549.27
# You earned €38.61 from selling your inventory. Your total is now €14587.88
# You earned €20.42 from selling your inventory. Your total is now €14608.30
# You earned €62.62 from selling your inventory. Your total is now €14670.92
# You earned €19.18 from selling your inventory. Your total is now €14690.10
# You earned €31.29 from selling your inventory. Your total is now €14721.39
# You earned €7.62 from selling your inventory. Your total is now €14729.01
# You earned €65.18 from selling your inventory. Your total is now €14794.19
# You earned €24.77 from selling your inventory. Your total is now €14818.97
# You earned €48.40 from selling your inventory. Your total is now €14867.36
# You earned €8.55 from selling your inventory. Your total is now €14875.92
# You earned €67.33 from selling your inventory. Your total is now €14943.25
# You earned €25.38 from selling your inventory. Your total is now €14968.63
# You earned €18.88 from selling your inventory. Your total is now €14987.51
# You earned €0.00 from selling your inventory. Your total is now €14987.51
# You earned €43.50 from selling your inventory. Your total is now €15031.00
# You earned €29.65 from selling your inventory. Your total is now €15060.65
# You earned €18.15 from selling your inventory. Your total is now €15078.80
# You earned €11.37 from selling your inventory. Your total is now €15090.17
# You earned €56.52 from selling your inventory. Your total is now €15146.69
# You earned €35.83 from selling your inventory. Your total is now €15182.53
# You earned €52.05 from selling your inventory. Your total is now €15234.57
# You earned €10.78 from selling your inventory. Your total is now €15245.36
# You earned €71.70 from selling your inventory. Your total is now €15317.05
# You earned €19.00 from selling your inventory. Your total is now €15336.05
# You earned €39.80 from selling your inventory. Your total is now €15375.85
# You earned €14.57 from selling your inventory. Your total is now €15390.42
# You earned €59.18 from selling your inventory. Your total is now €15449.61
# You earned €21.76 from selling your inventory. Your total is now €15471.37
# You earned €29.76 from selling your inventory. Your total is now €15501.13
# You earned €1.19 from selling your inventory. Your total is now €15502.32
# You earned €58.35 from selling your inventory. Your total is now €15560.68
# You earned €34.68 from selling your inventory. Your total is now €15595.36
# You earned €29.08 from selling your inventory. Your total is now €15624.44
# You earned €16.70 from selling your inventory. Your total is now €15641.14
# You earned €61.49 from selling your inventory. Your total is now €15702.63
# You earned €33.49 from selling your inventory. Your total is now €15736.13
# You earned €22.39 from selling your inventory. Your total is now €15758.51
# You earned €19.35 from selling your inventory. Your total is now €15777.86
# You earned €53.86 from selling your inventory. Your total is now €15831.72
# You earned €34.45 from selling your inventory. Your total is now €15866.17
# You earned €31.65 from selling your inventory. Your total is now €15897.82
# You earned €16.65 from selling your inventory. Your total is now €15914.47
# You earned €74.26 from selling your inventory. Your total is now €15988.72
# You earned €38.74 from selling your inventory. Your total is now €16027.46
# You earned €30.46 from selling your inventory. Your total is now €16057.92
# You earned €14.01 from selling your inventory. Your total is now €16071.93
# You earned €64.98 from selling your inventory. Your total is now €16136.91
# You earned €27.89 from selling your inventory. Your total is now €16164.80
# You earned €34.74 from selling your inventory. Your total is now €16199.53
# You earned €18.30 from selling your inventory. Your total is now €16217.84
# You earned €65.56 from selling your inventory. Your total is now €16283.40
# You earned €10.47 from selling your inventory. Your total is now €16293.87
# You earned €41.43 from selling your inventory. Your total is now €16335.30
# You earned €8.03 from selling your inventory. Your total is now €16343.33
# You earned €60.94 from selling your inventory. Your total is now €16404.27
# You earned €40.08 from selling your inventory. Your total is now €16444.35
# You earned €12.90 from selling your inventory. Your total is now €16457.25
# You earned €11.77 from selling your inventory. Your total is now €16469.02
# You earned €52.58 from selling your inventory. Your total is now €16521.59
# You earned €34.42 from selling your inventory. Your total is now €16556.02
# You earned €36.25 from selling your inventory. Your total is now €16592.27
# You earned €8.81 from selling your inventory. Your total is now €16601.08
# You earned €64.98 from selling your inventory. Your total is now €16666.06
# You earned €40.47 from selling your inventory. Your total is now €16706.53
# You earned €24.95 from selling your inventory. Your total is now €16731.48
# You earned €2.64 from selling your inventory. Your total is now €16734.11
# You earned €56.04 from selling your inventory. Your total is now €16790.15
# You earned €26.92 from selling your inventory. Your total is now €16817.07
# You earned €31.73 from selling your inventory. Your total is now €16848.80
# You earned €14.64 from selling your inventory. Your total is now €16863.43
# You earned €69.58 from selling your inventory. Your total is now €16933.01
# You earned €34.19 from selling your inventory. Your total is now €16967.20
# You earned €17.92 from selling your inventory. Your total is now €16985.12
# You earned €5.06 from selling your inventory. Your total is now €16990.18
# You earned €85.90 from selling your inventory. Your total is now €17076.08
# You earned €34.77 from selling your inventory. Your total is now €17110.85
# You earned €34.05 from selling your inventory. Your total is now €17144.90
# You earned €9.02 from selling your inventory. Your total is now €17153.92
# You earned €43.10 from selling your inventory. Your total is now €17197.01
# You earned €35.05 from selling your inventory. Your total is now €17232.06
# You earned €24.00 from selling your inventory. Your total is now €17256.07
# You earned €8.21 from selling your inventory. Your total is now €17264.28
# You earned €75.23 from selling your inventory. Your total is now €17339.50
# You earned €18.16 from selling your inventory. Your total is now €17357.67
# You earned €34.61 from selling your inventory. Your total is now €17392.28
# You earned €18.49 from selling your inventory. Your total is now €17410.77
# You earned €85.31 from selling your inventory. Your total is now €17496.08
# You earned €30.22 from selling your inventory. Your total is now €17526.30
# You earned €34.85 from selling your inventory. Your total is now €17561.15
# You earned €8.60 from selling your inventory. Your total is now €17569.75
# You earned €67.85 from selling your inventory. Your total is now €17637.59
# You earned €21.11 from selling your inventory. Your total is now €17658.71
# You earned €20.67 from selling your inventory. Your total is now €17679.38
# You earned €6.53 from selling your inventory. Your total is now €17685.91
# You earned €71.72 from selling your inventory. Your total is now €17757.63
# You earned €19.95 from selling your inventory. Your total is now €17777.58
# You earned €22.45 from selling your inventory. Your total is now €17800.03
# You earned €4.78 from selling your inventory. Your total is now €17804.81
# You earned €81.41 from selling your inventory. Your total is now €17886.22
# You earned €21.87 from selling your inventory. Your total is now €17908.10
# You earned €29.13 from selling your inventory. Your total is now €17937.22
# You earned €0.08 from selling your inventory. Your total is now €17937.30
# You earned €60.69 from selling your inventory. Your total is now €17997.99
# You earned €33.42 from selling your inventory. Your total is now €18031.41
# You earned €41.24 from selling your inventory. Your total is now €18072.65
# You earned €7.62 from selling your inventory. Your total is now €18080.28
# You earned €63.26 from selling your inventory. Your total is now €18143.54
# You earned €38.69 from selling your inventory. Your total is now €18182.23
# You earned €24.81 from selling your inventory. Your total is now €18207.04
# You earned €9.75 from selling your inventory. Your total is now €18216.79
# You earned €57.44 from selling your inventory. Your total is now €18274.23
# You earned €41.77 from selling your inventory. Your total is now €18316.00
# You earned €26.70 from selling your inventory. Your total is now €18342.70
# You earned €2.98 from selling your inventory. Your total is now €18345.68
# You earned €63.00 from selling your inventory. Your total is now €18408.67
# You earned €21.14 from selling your inventory. Your total is now €18429.81
# You earned €36.58 from selling your inventory. Your total is now €18466.39
# You earned €18.59 from selling your inventory. Your total is now €18484.98
# You earned €74.56 from selling your inventory. Your total is now €18559.54
# You earned €29.42 from selling your inventory. Your total is now €18588.95
# You earned €37.59 from selling your inventory. Your total is now €18626.55
# You earned €11.67 from selling your inventory. Your total is now €18638.21
# You earned €70.10 from selling your inventory. Your total is now €18708.31
# You earned €19.47 from selling your inventory. Your total is now €18727.78
# You earned €27.64 from selling your inventory. Your total is now €18755.42
# You earned €16.12 from selling your inventory. Your total is now €18771.54
# You earned €72.43 from selling your inventory. Your total is now €18843.97
# You earned €21.94 from selling your inventory. Your total is now €18865.90
# You earned €19.44 from selling your inventory. Your total is now €18885.35
# You earned €7.36 from selling your inventory. Your total is now €18892.71
# You earned €47.49 from selling your inventory. Your total is now €18940.20
# You earned €38.46 from selling your inventory. Your total is now €18978.67
# You earned €24.79 from selling your inventory. Your total is now €19003.46
# You earned €20.61 from selling your inventory. Your total is now €19024.07
# You earned €42.69 from selling your inventory. Your total is now €19066.76
# You earned €38.52 from selling your inventory. Your total is now €19105.28
# You earned €27.34 from selling your inventory. Your total is now €19132.62
# You earned €10.04 from selling your inventory. Your total is now €19142.66
# You earned €59.51 from selling your inventory. Your total is now €19202.17
# You earned €34.68 from selling your inventory. Your total is now €19236.85
# You earned €27.28 from selling your inventory. Your total is now €19264.13
# You earned €4.33 from selling your inventory. Your total is now €19268.46
# You earned €55.13 from selling your inventory. Your total is now €19323.59
# You earned €35.81 from selling your inventory. Your total is now €19359.40
# You earned €45.35 from selling your inventory. Your total is now €19404.75
# You earned €13.88 from selling your inventory. Your total is now €19418.63
# You earned €67.92 from selling your inventory. Your total is now €19486.55
# You earned €31.16 from selling your inventory. Your total is now €19517.71
# You earned €22.00 from selling your inventory. Your total is now €19539.70
# You earned €6.47 from selling your inventory. Your total is now €19546.18
# You earned €61.58 from selling your inventory. Your total is now €19607.76
# You earned €34.19 from selling your inventory. Your total is now €19641.95
# You earned €33.38 from selling your inventory. Your total is now €19675.33
# You earned €17.80 from selling your inventory. Your total is now €19693.13
# You earned €67.95 from selling your inventory. Your total is now €19761.07
# You earned €41.77 from selling your inventory. Your total is now €19802.85
# You earned €27.52 from selling your inventory. Your total is now €19830.36
# You earned €11.89 from selling your inventory. Your total is now €19842.25
# You earned €64.24 from selling your inventory. Your total is now €19906.49
# You earned €45.62 from selling your inventory. Your total is now €19952.11
# You earned €48.84 from selling your inventory. Your total is now €20000.95
# You earned €12.49 from selling your inventory. Your total is now €20013.44
# You earned €51.35 from selling your inventory. Your total is now €20064.79
# You earned €36.71 from selling your inventory. Your total is now €20101.50
# You earned €18.49 from selling your inventory. Your total is now €20119.99
# You earned €11.27 from selling your inventory. Your total is now €20131.25
# You earned €55.14 from selling your inventory. Your total is now €20186.40
# You earned €29.94 from selling your inventory. Your total is now €20216.33
# You earned €39.24 from selling your inventory. Your total is now €20255.58
# You earned €10.09 from selling your inventory. Your total is now €20265.67
# You earned €61.23 from selling your inventory. Your total is now €20326.90
# You earned €21.37 from selling your inventory. Your total is now €20348.27
# You earned €38.43 from selling your inventory. Your total is now €20386.71
# You earned €14.03 from selling your inventory. Your total is now €20400.74
# You earned €71.10 from selling your inventory. Your total is now €20471.83
# You earned €31.90 from selling your inventory. Your total is now €20503.74
# You earned €31.81 from selling your inventory. Your total is now €20535.55
# You earned €10.33 from selling your inventory. Your total is now €20545.87
# You earned €53.88 from selling your inventory. Your total is now €20599.75
# You earned €17.30 from selling your inventory. Your total is now €20617.05
# You earned €55.84 from selling your inventory. Your total is now €20672.89
# You earned €11.53 from selling your inventory. Your total is now €20684.42
# You earned €82.59 from selling your inventory. Your total is now €20767.01
# You earned €26.70 from selling your inventory. Your total is now €20793.71
# You earned €28.89 from selling your inventory. Your total is now €20822.60
# You earned €9.27 from selling your inventory. Your total is now €20831.87
# You earned €53.23 from selling your inventory. Your total is now €20885.11
# You earned €34.51 from selling your inventory. Your total is now €20919.62
# You earned €41.12 from selling your inventory. Your total is now €20960.73
# You earned €12.12 from selling your inventory. Your total is now €20972.85
# You earned €47.10 from selling your inventory. Your total is now €21019.95
# You earned €32.31 from selling your inventory. Your total is now €21052.26
# You earned €29.09 from selling your inventory. Your total is now €21081.34
# You earned €11.47 from selling your inventory. Your total is now €21092.81
# You earned €92.34 from selling your inventory. Your total is now €21185.15
# You earned €39.77 from selling your inventory. Your total is now €21224.92
# You earned €13.16 from selling your inventory. Your total is now €21238.08
# You earned €13.84 from selling your inventory. Your total is now €21251.92
# You earned €64.99 from selling your inventory. Your total is now €21316.91
# You earned €30.63 from selling your inventory. Your total is now €21347.54
# You earned €29.25 from selling your inventory. Your total is now €21376.79
# You earned €14.46 from selling your inventory. Your total is now €21391.26
# You earned €60.22 from selling your inventory. Your total is now €21451.47
# You earned €45.26 from selling your inventory. Your total is now €21496.73
# You earned €35.42 from selling your inventory. Your total is now €21532.15
# You earned €8.33 from selling your inventory. Your total is now €21540.48
# You earned €48.54 from selling your inventory. Your total is now €21589.02
# You earned €22.18 from selling your inventory. Your total is now €21611.20
# You earned €31.01 from selling your inventory. Your total is now €21642.20
# You earned €19.52 from selling your inventory. Your total is now €21661.72
# You earned €62.89 from selling your inventory. Your total is now €21724.61
# You earned €40.16 from selling your inventory. Your total is now €21764.77
# You earned €42.41 from selling your inventory. Your total is now €21807.18
# You earned €16.17 from selling your inventory. Your total is now €21823.35
# You earned €67.34 from selling your inventory. Your total is now €21890.69
# You earned €32.06 from selling your inventory. Your total is now €21922.75
# You earned €18.75 from selling your inventory. Your total is now €21941.50
# You earned €21.32 from selling your inventory. Your total is now €21962.83
# You earned €49.96 from selling your inventory. Your total is now €22012.79
# ...
# You earned €11.92 from selling your inventory. Your total is now €80232.70
# You earned €68.49 from selling your inventory. Your total is now €80301.19
# You earned €36.75 from selling your inventory. Your total is now €80337.94
# You earned €29.57 from selling your inventory. Your total is now €80367.51
# You earned €20.94 from selling your inventory. Your total is now €80388.45
# You earned €42.59 from selling your inventory. Your total is now €80431.04
# You earned €17.14 from selling your inventory. Your total is now €80448.18
# You earned €34.48 from selling your inventory. Your total is now €80482.66
# You earned €19.50 from selling your inventory. Your total is now €80502.16
# You earned €68.55 from selling your inventory. Your total is now €80570.71
# You earned €27.62 from selling your inventory. Your total is now €80598.32
# You earned €28.77 from selling your inventory. Your total is now €80627.09
# You earned €15.86 from selling your inventory. Your total is now €80642.95
# You earned €61.26 from selling your inventory. Your total is now €80704.21
# You earned €19.19 from selling your inventory. Your total is now €80723.40
# You earned €34.21 from selling your inventory. Your total is now €80757.61
# You earned €2.99 from selling your inventory. Your total is now €80760.60
# You earned €57.53 from selling your inventory. Your total is now €80818.13
# You earned €26.41 from selling your inventory. Your total is now €80844.54
# You earned €35.54 from selling your inventory. Your total is now €80880.08
# You earned €3.67 from selling your inventory. Your total is now €80883.75
# You earned €73.37 from selling your inventory. Your total is now €80957.12
# You earned €29.32 from selling your inventory. Your total is now €80986.44
# You earned €34.08 from selling your inventory. Your total is now €81020.52
# You earned €13.91 from selling your inventory. Your total is now €81034.43
# You earned €66.42 from selling your inventory. Your total is now €81100.85
# You earned €24.79 from selling your inventory. Your total is now €81125.65
# You earned €35.09 from selling your inventory. Your total is now €81160.74
# You earned €7.51 from selling your inventory. Your total is now €81168.25
# You earned €69.10 from selling your inventory. Your total is now €81237.35
# You earned €34.35 from selling your inventory. Your total is now €81271.70
# You earned €44.17 from selling your inventory. Your total is now €81315.87
# You earned €12.31 from selling your inventory. Your total is now €81328.18
# You earned €57.59 from selling your inventory. Your total is now €81385.77
# You earned €24.73 from selling your inventory. Your total is now €81410.50
# You earned €32.21 from selling your inventory. Your total is now €81442.72
# You earned €11.79 from selling your inventory. Your total is now €81454.51
# You earned €52.98 from selling your inventory. Your total is now €81507.48
# You earned €34.56 from selling your inventory. Your total is now €81542.04
# You earned €41.49 from selling your inventory. Your total is now €81583.53
# You earned €13.84 from selling your inventory. Your total is now €81597.37
# You earned €71.96 from selling your inventory. Your total is now €81669.32
# You earned €31.47 from selling your inventory. Your total is now €81700.79
# You earned €43.41 from selling your inventory. Your total is now €81744.20
# You earned €1.50 from selling your inventory. Your total is now €81745.71
# You earned €61.58 from selling your inventory. Your total is now €81807.29
# You earned €27.02 from selling your inventory. Your total is now €81834.31
# You earned €31.92 from selling your inventory. Your total is now €81866.23
# You earned €0.89 from selling your inventory. Your total is now €81867.13
# You earned €58.34 from selling your inventory. Your total is now €81925.46
# You earned €29.79 from selling your inventory. Your total is now €81955.25
# You earned €24.38 from selling your inventory. Your total is now €81979.63
# You earned €13.18 from selling your inventory. Your total is now €81992.81
# You earned €56.06 from selling your inventory. Your total is now €82048.88
# You earned €34.33 from selling your inventory. Your total is now €82083.21
# You earned €17.33 from selling your inventory. Your total is now €82100.54
# You earned €14.81 from selling your inventory. Your total is now €82115.35
# You earned €78.41 from selling your inventory. Your total is now €82193.76
# You earned €44.17 from selling your inventory. Your total is now €82237.93
# You earned €40.72 from selling your inventory. Your total is now €82278.66
# You earned €8.36 from selling your inventory. Your total is now €82287.01
# You earned €55.31 from selling your inventory. Your total is now €82342.32
# You earned €27.83 from selling your inventory. Your total is now €82370.15
# You earned €47.57 from selling your inventory. Your total is now €82417.71
# You earned €16.10 from selling your inventory. Your total is now €82433.81
# You earned €61.63 from selling your inventory. Your total is now €82495.44
# You earned €41.71 from selling your inventory. Your total is now €82537.15
# You earned €39.51 from selling your inventory. Your total is now €82576.67
# You earned €1.44 from selling your inventory. Your total is now €82578.11
# You earned €47.53 from selling your inventory. Your total is now €82625.64
# You earned €29.28 from selling your inventory. Your total is now €82654.92
# You earned €37.13 from selling your inventory. Your total is now €82692.05
# You earned €15.14 from selling your inventory. Your total is now €82707.19
# You earned €79.88 from selling your inventory. Your total is now €82787.07
# You earned €36.77 from selling your inventory. Your total is now €82823.84
# You earned €33.96 from selling your inventory. Your total is now €82857.79
# You earned €13.24 from selling your inventory. Your total is now €82871.03
# You earned €80.10 from selling your inventory. Your total is now €82951.13
# You earned €40.02 from selling your inventory. Your total is now €82991.15
# You earned €40.07 from selling your inventory. Your total is now €83031.22
# You earned €6.47 from selling your inventory. Your total is now €83037.68
# You earned €51.21 from selling your inventory. Your total is now €83088.89
# You earned €29.50 from selling your inventory. Your total is now €83118.39
# You earned €30.42 from selling your inventory. Your total is now €83148.81
# You earned €23.26 from selling your inventory. Your total is now €83172.07
# You earned €59.10 from selling your inventory. Your total is now €83231.17
# You earned €30.83 from selling your inventory. Your total is now €83262.00
# You earned €43.52 from selling your inventory. Your total is now €83305.52
# You earned €10.43 from selling your inventory. Your total is now €83315.95
# You earned €56.01 from selling your inventory. Your total is now €83371.96
# You earned €29.53 from selling your inventory. Your total is now €83401.49
# You earned €32.13 from selling your inventory. Your total is now €83433.61
# You earned €11.41 from selling your inventory. Your total is now €83445.02
# You earned €45.64 from selling your inventory. Your total is now €83490.66
# You earned €33.55 from selling your inventory. Your total is now €83524.21
# You earned €19.34 from selling your inventory. Your total is now €83543.55
# You earned €27.50 from selling your inventory. Your total is now €83571.05
# You earned €43.72 from selling your inventory. Your total is now €83614.77
# You earned €34.10 from selling your inventory. Your total is now €83648.87
# You earned €42.98 from selling your inventory. Your total is now €83691.86
# You earned €6.48 from selling your inventory. Your total is now €83698.34
# You earned €66.51 from selling your inventory. Your total is now €83764.85
# You earned €44.83 from selling your inventory. Your total is now €83809.68
# You earned €35.29 from selling your inventory. Your total is now €83844.97
# You earned €11.24 from selling your inventory. Your total is now €83856.21
# You earned €44.86 from selling your inventory. Your total is now €83901.07
# You earned €41.49 from selling your inventory. Your total is now €83942.56
# You earned €22.87 from selling your inventory. Your total is now €83965.43
# You earned €13.57 from selling your inventory. Your total is now €83979.01
# You earned €77.83 from selling your inventory. Your total is now €84056.84
# You earned €20.59 from selling your inventory. Your total is now €84077.42
# You earned €53.49 from selling your inventory. Your total is now €84130.92
# You earned €2.25 from selling your inventory. Your total is now €84133.17
# You earned €72.08 from selling your inventory. Your total is now €84205.25
# You earned €34.22 from selling your inventory. Your total is now €84239.47
# You earned €31.21 from selling your inventory. Your total is now €84270.68
# You earned €15.28 from selling your inventory. Your total is now €84285.97
# You earned €66.53 from selling your inventory. Your total is now €84352.50
# You earned €37.13 from selling your inventory. Your total is now €84389.62
# You earned €46.54 from selling your inventory. Your total is now €84436.17
# You earned €9.63 from selling your inventory. Your total is now €84445.80
# You earned €60.34 from selling your inventory. Your total is now €84506.14
# You earned €40.06 from selling your inventory. Your total is now €84546.20
# You earned €47.44 from selling your inventory. Your total is now €84593.64
# You earned €0.00 from selling your inventory. Your total is now €84593.64
# You earned €70.32 from selling your inventory. Your total is now €84663.96
# You earned €29.05 from selling your inventory. Your total is now €84693.01
# You earned €18.09 from selling your inventory. Your total is now €84711.10
# You earned €19.53 from selling your inventory. Your total is now €84730.62
# You earned €53.67 from selling your inventory. Your total is now €84784.29
# You earned €35.66 from selling your inventory. Your total is now €84819.95
# You earned €27.35 from selling your inventory. Your total is now €84847.30
# You earned €22.93 from selling your inventory. Your total is now €84870.24
# You earned €57.96 from selling your inventory. Your total is now €84928.19
# You earned €24.30 from selling your inventory. Your total is now €84952.49
# You earned €37.42 from selling your inventory. Your total is now €84989.91
# You earned €5.50 from selling your inventory. Your total is now €84995.41
# You earned €69.67 from selling your inventory. Your total is now €85065.08
# You earned €31.13 from selling your inventory. Your total is now €85096.21
# You earned €31.49 from selling your inventory. Your total is now €85127.70
# You earned €13.14 from selling your inventory. Your total is now €85140.84
# You earned €52.94 from selling your inventory. Your total is now €85193.78
# You earned €39.87 from selling your inventory. Your total is now €85233.65
# You earned €38.08 from selling your inventory. Your total is now €85271.73
# You earned €12.10 from selling your inventory. Your total is now €85283.82
# You earned €75.05 from selling your inventory. Your total is now €85358.87
# You earned €25.98 from selling your inventory. Your total is now €85384.85
# You earned €41.03 from selling your inventory. Your total is now €85425.88
# You earned €13.12 from selling your inventory. Your total is now €85439.00
# You earned €68.21 from selling your inventory. Your total is now €85507.21
# You earned €28.01 from selling your inventory. Your total is now €85535.22
# You earned €29.42 from selling your inventory. Your total is now €85564.64
# You earned €20.99 from selling your inventory. Your total is now €85585.63
# You earned €47.62 from selling your inventory. Your total is now €85633.25
# You earned €33.69 from selling your inventory. Your total is now €85666.93
# You earned €37.29 from selling your inventory. Your total is now €85704.22
# You earned €5.13 from selling your inventory. Your total is now €85709.35
# You earned €68.42 from selling your inventory. Your total is now €85777.77
# You earned €37.96 from selling your inventory. Your total is now €85815.73
# You earned €29.80 from selling your inventory. Your total is now €85845.53
# You earned €13.66 from selling your inventory. Your total is now €85859.20
# You earned €59.26 from selling your inventory. Your total is now €85918.46
# You earned €30.00 from selling your inventory. Your total is now €85948.46
# You earned €33.16 from selling your inventory. Your total is now €85981.62
# You earned €9.98 from selling your inventory. Your total is now €85991.60
# You earned €57.69 from selling your inventory. Your total is now €86049.29
# You earned €27.69 from selling your inventory. Your total is now €86076.97
# You earned €54.20 from selling your inventory. Your total is now €86131.17
# You earned €12.80 from selling your inventory. Your total is now €86143.97
# You earned €56.61 from selling your inventory. Your total is now €86200.59
# You earned €37.59 from selling your inventory. Your total is now €86238.18
# You earned €33.61 from selling your inventory. Your total is now €86271.79
# You earned €0.00 from selling your inventory. Your total is now €86271.79
# You earned €61.21 from selling your inventory. Your total is now €86333.01
# You earned €27.42 from selling your inventory. Your total is now €86360.43
# You earned €37.48 from selling your inventory. Your total is now €86397.91
# You earned €11.52 from selling your inventory. Your total is now €86409.43
# You earned €64.93 from selling your inventory. Your total is now €86474.36
# You earned €42.49 from selling your inventory. Your total is now €86516.85
# You earned €43.08 from selling your inventory. Your total is now €86559.93
# You earned €26.10 from selling your inventory. Your total is now €86586.03
# You earned €56.25 from selling your inventory. Your total is now €86642.29
# You earned €23.03 from selling your inventory. Your total is now €86665.32
# You earned €30.78 from selling your inventory. Your total is now €86696.10
# You earned €1.43 from selling your inventory. Your total is now €86697.53
# You earned €64.99 from selling your inventory. Your total is now €86762.52
# You earned €28.19 from selling your inventory. Your total is now €86790.71
# You earned €27.34 from selling your inventory. Your total is now €86818.05
# You earned €17.41 from selling your inventory. Your total is now €86835.46
# You earned €81.39 from selling your inventory. Your total is now €86916.85
# You earned €31.96 from selling your inventory. Your total is now €86948.82
# You earned €16.40 from selling your inventory. Your total is now €86965.22
# You earned €15.60 from selling your inventory. Your total is now €86980.82
# You earned €50.84 from selling your inventory. Your total is now €87031.65
# You earned €30.92 from selling your inventory. Your total is now €87062.57
# You earned €35.76 from selling your inventory. Your total is now €87098.33
# You earned €12.85 from selling your inventory. Your total is now €87111.19
# You earned €53.86 from selling your inventory. Your total is now €87165.05
# You earned €34.86 from selling your inventory. Your total is now €87199.91
# You earned €38.27 from selling your inventory. Your total is now €87238.18
# You earned €17.58 from selling your inventory. Your total is now €87255.77
# You earned €60.33 from selling your inventory. Your total is now €87316.09
# You earned €25.18 from selling your inventory. Your total is now €87341.27
# You earned €33.78 from selling your inventory. Your total is now €87375.06
# You earned €15.26 from selling your inventory. Your total is now €87390.32
# You earned €52.03 from selling your inventory. Your total is now €87442.35
# You earned €27.77 from selling your inventory. Your total is now €87470.12
# You earned €36.33 from selling your inventory. Your total is now €87506.45
# You earned €15.59 from selling your inventory. Your total is now €87522.04
# You earned €61.80 from selling your inventory. Your total is now €87583.84
# 5000 days have passed! Your final score is €87583.84. Your script should stop here.
# You earned €29.72 from selling your inventory. Your total is now €87613.56
# 5001 days have passed! Your final score is €87613.56. Your script should stop here.
